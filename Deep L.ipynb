# %%
import pandas as pd 
import os 
os.chdir('C:\\Users\\User\\Downloads')
df = pd.read_csv('data2.csv')
df.sample(20)
# Out:
#      Comp_ID  N_shift  H_shift
# 1433     LYS    0.000   1.4600
# 504      LEU    0.000   0.3230
# 269      ALA    0.000   0.9980
# 1709     GLU  129.507   1.8060
# 1524     LYS    0.000   0.8940
# 1554     ILE  122.910   1.0400
# 1173     ASN    0.000   2.2260
# 1330     VAL    0.000   0.0390
# 1593     ILE    0.000   1.0360
# 1601     ILE    0.000   0.8190
# 1541     TRP    0.000   2.8490
# 1693     GLU  126.400   8.6149
# 854      GLY  105.163   8.3201
# 54       TYR    0.000   4.5990
# 783      SER    0.000   3.5700
# 1742     GLU    0.000   1.5030
# 1521     LYS    0.000   1.3790
# 1270     VAL    0.000   8.7870
# 1589     ILE    0.000   1.6810
# 374      LEU    0.000   8.1900

# %%
classes = df['Comp_ID'].unique()
print(classes)
# Out:
# ['TYR' 'PHE' 'HIS' 'ALA' 'LEU' 'ARG' 'GLN' 'MET' 'SER' 'CYS' 'GLY' 'THR'
#  'ASP' 'ASN' 'VAL' 'LYS' 'TRP' 'ILE' 'GLU' 'NAG' 'MAN' 'FUC' 'PRO']

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


df = pd.read_csv('data2.csv')
label_encoder = LabelEncoder()
df['Comp_ID'] = label_encoder.fit_transform(df['Comp_ID'])

X = df[['N_shift', 'H_shift']].values
y = df['Comp_ID'].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)


model = Sequential([
    Dense(32, activation='relu', input_shape=(2,)),
    Dense(64, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# D:\Anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.0636 - loss: 3.1184 - val_accuracy: 0.1200 - val_loss: 2.9977
# Epoch 2/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1366 - loss: 2.9362 - val_accuracy: 0.1200 - val_loss: 2.8416
# Epoch 3/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1363 - loss: 2.7547 - val_accuracy: 0.1133 - val_loss: 2.7683
# Epoch 4/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1345 - loss: 2.7143 - val_accuracy: 0.1300 - val_loss: 2.7365
# Epoch 5/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1514 - loss: 2.6661 - val_accuracy: 0.1267 - val_loss: 2.7165
# Epoch 6/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1612 - loss: 2.6643 - val_accuracy: 0.1300 - val_loss: 2.7078
# Epoch 7/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1599 - loss: 2.6220 - val_accuracy: 0.1233 - val_loss: 2.6885
# Epoch 8/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1595 - loss: 2.6247 - val_accuracy: 0.1233 - val_loss: 2.6752
# Epoch 9/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1514 - loss: 2.6004 - val_accuracy: 0.1300 - val_loss: 2.6680
# Epoch 10/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1653 - loss: 2.5900 - val_accuracy: 0.1267 - val_loss: 2.6590
# Epoch 11/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1493 - loss: 2.5993 - val_accuracy: 0.1267 - val_loss: 2.6509
# Epoch 12/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1665 - loss: 2.5673 - val_accuracy: 0.1300 - val_loss: 2.6470
# Epoch 13/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1792 - loss: 2.5564 - val_accuracy: 0.1233 - val_loss: 2.6392
# Epoch 14/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1585 - loss: 2.5586 - val_accuracy: 0.1333 - val_loss: 2.6350
# Epoch 15/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1763 - loss: 2.5401 - val_accuracy: 0.1333 - val_loss: 2.6238
# Epoch 16/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1804 - loss: 2.5182 - val_accuracy: 0.1333 - val_loss: 2.6195
# Epoch 17/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1682 - loss: 2.5343 - val_accuracy: 0.1300 - val_loss: 2.6225
# Epoch 18/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1860 - loss: 2.4999 - val_accuracy: 0.1367 - val_loss: 2.6159
# Epoch 19/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1856 - loss: 2.5310 - val_accuracy: 0.1400 - val_loss: 2.6077
# Epoch 20/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1822 - loss: 2.5174 - val_accuracy: 0.1433 - val_loss: 2.6119
# Epoch 21/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1817 - loss: 2.4795 - val_accuracy: 0.1433 - val_loss: 2.6129
# Epoch 22/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1693 - loss: 2.5199 - val_accuracy: 0.1333 - val_loss: 2.6015
# Epoch 23/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1549 - loss: 2.5186 - val_accuracy: 0.1300 - val_loss: 2.5999
# Epoch 24/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1873 - loss: 2.4627 - val_accuracy: 0.1300 - val_loss: 2.5979
# Epoch 25/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1779 - loss: 2.4970 - val_accuracy: 0.1367 - val_loss: 2.5949
# Epoch 26/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1824 - loss: 2.4876 - val_accuracy: 0.1367 - val_loss: 2.5994
# Epoch 27/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1710 - loss: 2.5066 - val_accuracy: 0.1433 - val_loss: 2.5999
# Epoch 28/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1838 - loss: 2.4884 - val_accuracy: 0.1467 - val_loss: 2.5955
# Epoch 29/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1784 - loss: 2.4448 - val_accuracy: 0.1433 - val_loss: 2.5961
# Epoch 30/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1836 - loss: 2.4598 - val_accuracy: 0.1333 - val_loss: 2.5927

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1784 - loss: 2.4602
# Test Accuracy: 0.1626666635274887
